# %%
import pandas as pd

# Load it
df = pd.read_csv(r'C:\Users\theri\Downloads\datasetPandas\single_amazon_laptop_messy_dataset_1-10.csv')

df1 = df.groupby('brand')['price'].idxmax()

# Use that index to get the full rows
df1 = df.loc[df1][['brand', 'product_title', 'price']]
df1
# Out:
#          brand                                      product_title   price
# 169       ASUS  ASUS ROG Strix SCAR 18,Intel Core Ultra 9 275H...  484990
# 36   Alienware  Alienware 16 Area-51 Gaming Laptop, AI Enabled...  499990
# 93       Apple  Apple 2024 MacBook Pro Laptop with M4 Pro chip...  279990
# 30        Dell  Dell 15 Laptop DC15250-15.6-inch FHD 120Hz Dis...   68490
# 38     FUTOPIA  ULTIMUS APEX Laptop Intel Celeron Dual Core 8 ...   16990
# 129   GIGABYTE  GIGABYTE AERO 16 YE5, 16.0" Inch UHD+ OLED 60H...  174990
# 183    Generic  Dell_Model 5420 | i5 11th Gen Processor | 16GB...   32995
# 140         HP  HP OmniBook Ultra Flip Next Gen AI PC Ultra 7 ...  180490
# 31         JIO  JioBook 11 with Lifetime Office | Android 4G L...   14990
# 81      Lenovo  Lenovo Thinkpad P16V Gen 2 21KX002GUS 16" Mobi...  251500
# 70         MSI  MSI Titan 18 HX AI,Intel Series 2 Core Ultra 9...  484990
# 144  Microsoft  Microsoft New Surface Laptop (7th Edition) - W...  150990
# ...
